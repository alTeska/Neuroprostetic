# %% [markdown]
# # Exercise 7 - Simplified Cochlear Implant

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import butter, lfilter, filtfilt

from matplotlib import rcParams
% matplotlib inline

# %%
rcParams.update({'font.size': 20})

# %% [markdown]
# ## Corner Frequencies for 4 different Numbers of Electrodes

# %%
num_electrodes = [3, 6, 12, 22]
f_min = 200
f_max = 8000
fs = 1000

# %%
corner_frequencies3  = np.around( np.logspace(np.log10(200), np.log10(8000), num=4) )
corner_frequencies6  = np.around( np.logspace(np.log10(200), np.log10(8000), num=6) )
corner_frequencies12 = np.around( np.logspace(np.log10(200), np.log10(8000), num=12) )
corner_frequencies22 = np.around( np.logspace(np.log10(200), np.log10(8000), num=22) )
corner_frequencies3
# Out:
# array([ 200.,  684., 2339., 8000.])

# %% [markdown]
# ## Filter Banks for Each electrode

# %%
def butter_bandpass(lowcut, highcut, fs, order=8):
    nyq = 2 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

def butter_bandpass_filtfilt(data, lowcut, highcut, fs, order=8):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = lfilter(b, a, data)
    return filtfilt(b, a, data)

# %%
def create_filters(corner_frequencies, fs, order=8):
    l = len(corner_frequencies)
    butter_bandpasses = np.zeros((l-1,2))
    butter_bandpasses = {}
    
    for i in np.arange(0, l-1):
        lowcut = (corner_frequencies[i])
        highcut = (corner_frequencies[i+1]) 
        print(lowcut, highcut)
        butter_bandpasses[i] = butter_bandpass(lowcut, highcut, fs, order=order)
    return butter_bandpasses

# %%
bb3  = create_filters(corner_frequencies3 , 1000, order=2)
# bb6  = create_filters(corner_frequencies6 , 10)
# bb12 = create_filters(corner_frequencies12, 10)
# bb22 = create_filters(corner_frequencies22, 10)
# bb3
# Out:
# 200.0 684.0
# 684.0 2339.0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-3258d9947f30> in <module>()
#       1
# ----> 2 bb3  = create_filters(corner_frequencies3 , 1000, order=2)
#       3 # bb6  = create_filters(corner_frequencies6 , 10)
#       4 # bb12 = create_filters(corner_frequencies12, 10)
#       5 # bb22 = create_filters(corner_frequencies22, 10)
#
# <ipython-input-42-dfed878d63ba> in create_filters(corner_frequencies, fs, order)
#       8         highcut = (corner_frequencies[i+1])
#       9         print(lowcut, highcut)
# ---> 10         butter_bandpasses[i] = butter_bandpass(lowcut, highcut, fs, order=order)
#      11     return butter_bandpasses
#
# <ipython-input-39-22fb41786c85> in butter_bandpass(lowcut, highcut, fs, order)
#       3     low = lowcut / nyq
#       4     high = highcut / nyq
# ----> 5     b, a = butter(order, [low, high], btype='band')
#       6     return b, a
#       7
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/signal/filter_design.py in butter(N, Wn, btype, analog, output)
#    2455     """
#    2456     return iirfilter(N, Wn, btype=btype, analog=analog,
# -> 2457                      output=output, ftype='butter')
#    2458
#    2459
#
# ~/anaconda3/lib/python3.6/site-packages/scipy/signal/filter_design.py in iirfilter(N, Wn, rp, rs, btype, analog, ftype, output)
#    1985     if not analog:
#    1986         if numpy.any(Wn <= 0) or numpy.any(Wn >= 1):
# -> 1987             raise ValueError("Digital filter critical frequencies "
#    1988                              "must be 0 < Wn < 1")
#    1989         fs = 2.0
#
# ValueError: Digital filter critical frequencies must be 0 < Wn < 1

# %%
# from scipy.signal import iirfilter
# iirfilter?

# %% [markdown]
# ## Loading Audio Signal
